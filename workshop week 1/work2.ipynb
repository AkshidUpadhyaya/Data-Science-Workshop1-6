# %%
# 1. Create the list
numbers = [5, 10, 15, 20, 25]

# 2. Use the built-in sum() function
total_sum = sum(numbers)

# Print the result
print("The total sum is:", total_sum)
# Out:
# The total sum is: 75
