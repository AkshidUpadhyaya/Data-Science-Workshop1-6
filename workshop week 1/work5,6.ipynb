# %%
# Task 5: Create and Access
user_info = {'name': 'Alice', 'age': 25, 'city': 'Kathmandu'}
print("Age is:", user_info['age'])
# Out:
# Age is: 25

# %%
# Task 6: Adding a pair
my_dict = {'a': 10, 'b': 20}
my_dict['c'] = 30
print("Updated Dictionary:", my_dict)
# Out:
# Updated Dictionary: {'a': 10, 'b': 20, 'c': 30}
