# %%
# Task 7: Adding
my_set = {1, 2, 3, 4}
my_set.add(5)
print("Set after adding 5:", my_set)
# Out:
# Set after adding 5: {1, 2, 3, 4, 5}

# %%
# Task 8: Intersection
set_a = {1, 2, 3}
set_b = {3, 4, 5}
common_items = set_a.intersection(set_b)
print("Intersection (common items):", common_items)
# Out:
# Intersection (common items): {3}
