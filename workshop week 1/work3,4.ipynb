# %%
# Task 3: Accessing
my_tuple = (1, 2, 3, 4, 5)
third_element = my_tuple[2]  # Index 2 is the 3rd item
print("Third element:", third_element)
# Out:
# Third element: 3

# %%
# Task 4: Conversion
small_tuple = (10, 20, 30)
temp_list = list(small_tuple) # Convert to list
temp_list.append(40)          # Now we can add 40
final_tuple = tuple(temp_list) # Convert back
print("Updated Tuple:", final_tuple)
# Out:
# Updated Tuple: (10, 20, 30, 40)
